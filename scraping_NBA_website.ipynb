# %% [markdown]
# # Scraping the NBA website with `nba-scraper`
#
# https://pypi.org/project/nba-scraper/
#
# Potential tutorials to consider (alternative to `nba-scraper`):
#
# http://savvastjortjoglou.com/nba-draft-part01-scraping.html
#
# https://www.playingnumbers.com/2019/12/how-to-get-nba-data-using-the-nba_api-python-module-beginner/
#
# https://medium.com/@irenenafula/data-analysis-project-web-scraping-nba-stats-part-1-cc425dd9da84
#
# I am going to start extracting data from the NBA website and see what it looks like.

# %%
import nba_scraper.nba_scraper as ns

# playing with game IDs

nba_df = ns.scrape_game([21800001, 21800002])
nba_df.head()
# Out:
# Scraping game id: 0021800001
# [1610612738]
# Scraping game id: 0021800002
# [1610612744]
#       game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 0  0021800001         2            12                   0       1
# 1  0021800001         4            10                   0       1
# 2  0021800001         7             2                   1       1
# 3  0021800001         8             4                   0       1
# 4  0021800001        10             2                   1       1
#
#   wctimestring pctimestring                               homedescription  \
# 0      8:03 PM        12:00                                          None
# 1      8:03 PM        12:00  Jump Ball Horford vs. Embiid: Tip to Simmons
# 2      8:03 PM        11:40                                          None
# 3      8:04 PM        11:40                               CELTICS Rebound
# 4      8:04 PM        11:15                  MISS Tatum 25' 3PT Jump Shot
#
# ...

# %% [markdown]
# It looks like with `scrape_game` I obtain the chronological series of events in a game and who was involved.
#
# It is not easy to determine the correspondence between a game ID and the game details (season, date, teams, etc).
#
# Let's see what information can we get from a whole season.

# %%
#scrape a season
nbaseas_df = ns.scrape_season(2019)
head(nbaseas_df)
# Out:
# Scraping game id: 0021800001
# [1610612738]
# Scraping game id: 0021800002
# [1610612744]
# Scraping game id: 0021800003
# [1610612766]
# Scraping game id: 0021800004
# [1610612765]
# Scraping game id: 0021800005
# [1610612754]
# Scraping game id: 0021800006
# [1610612753]
# Scraping game id: 0021800007
# [1610612752]
# Scraping game id: 0021800008
# [1610612761]
# Scraping game id: 0021800009
# [1610612745]
# Scraping game id: 0021800010
# [1610612759]
# Scraping game id: 0021800011
# [1610612758]
# Scraping game id: 0021800012
# [1610612746]
# Scraping game id: 0021800013
# [1610612756]
# Scraping game id: 0021800014
# [1610612755]
# Scraping game id: 0021800015
# [1610612764]
# Scraping game id: 0021800016
# [1610612757]
# Scraping game id: 0021800017
# [1610612753]
# Scraping game id: 0021800018
# [1610612751]
# Scraping game id: 0021800019
# [1610612761]
# Scraping game id: 0021800020
# [1610612763]
# Scraping game id: 0021800021
# [1610612750]
# Scraping game id: 0021800022
# ...

# %% [markdown]
# It seems that `nba_scraper` is very limited: only game, season or date interval stats can be accessed. No player or team based search utilities.
#
# So we have installed `nba_api` using `pip` and we will try this following this tuytorial first
# https://www.playingnumbers.com/2019/12/how-to-get-nba-data-using-the-nba_api-python-module-beginner/
